# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import collections

# %%
categories = ['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health']

n = 500

data = {
    'Date': pd.date_range('2021-01-01', periods=n),
    'Category': [random.choice(categories) for _ in range(n)],
    'Likes': np.random.randint(0, 10000, size=n)
}

df = pd.DataFrame(data)

print("DataFrame Head:")
print(df.head(20))

print("\nDataFrame Information:")
print(df.info())

print("\nDataFrame Description:")
print(df.describe())

category_counts = df[['Category']].value_counts()
print("\nCount of each 'Category' element:")
print(category_counts)
# Out:
# DataFrame Head:
#          Date Category  Likes
# 0  2021-01-01   Family   9622
# 1  2021-01-02  Fitness   1738
# 2  2021-01-03  Culture   4873
# 3  2021-01-04   Family    496
# 4  2021-01-05   Travel   7461
# 5  2021-01-06  Fashion   8669
# 6  2021-01-07   Family   9679
# 7  2021-01-08     Food   6281
# 8  2021-01-09    Music   3538
# 9  2021-01-10   Family   7936
# 10 2021-01-11   Family    167
# 11 2021-01-12   Travel   3995
# 12 2021-01-13   Family   2948
# 13 2021-01-14    Music   5767
# 14 2021-01-15   Health   2197
# 15 2021-01-16    Music   4167
# 16 2021-01-17  Fitness   3270
# 17 2021-01-18  Fashion   6257
# 18 2021-01-19   Family   4750
# 19 2021-01-20   Family   8609
#
# DataFrame Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      500 non-null    datetime64[ns]
#  1   Category  500 non-null    object
# ...

# %%
df.dropna(inplace=True)

df.drop_duplicates(inplace=True)

df['Date'] = pd.to_datetime(df['Date'])

df['Likes'] = df['Likes'].astype(int)

# %%
sns.histplot(df['Likes'])
plt.show()

sns.boxplot(x='Category', y='Likes', data=df)
plt.show()

print("Total Likes:", df['Likes'].sum())

print(df.groupby('Category')['Likes'].sum())
# Out:
# C:\Abdullah\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Total Likes: 2477231
# Category
# Culture    305449
# Family     396462
# Fashion    286744
# Fitness    333414
# Food       298689
# Health     241403
# Music      306879
# Travel     308191
# Name: Likes, dtype: int32

# %%
df_group = date_subset.groupby(['Date', 'Category'])['Likes'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='Likes', hue='Category', data=df_group)
plt.xticks(rotation=50)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
# Out:
# C:\Abdullah\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Abdullah\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_filtered = df[df['Category'].isin(['Fitness','Health'])]
df_filtered1 = df[df['Category'].isin(['Food', 'Travel', 'Fashion', 'Fitness', 'Music', 'Culture', 'Family', 'Health'])]

# %%
fig = plt.figure(figsize=(20,6))

ax0 = fig.add_subplot(1,2,1)
ax1 = fig.add_subplot(1,2,2)

sns.boxplot(x="Category", y="Likes", data=df_filtered, ax=ax0, vert=False)
ax0.set_title('Box plot of Category with respect to Likes')
ax0.set_xlabel('Likes')
ax0.set_ylabel('Category')

sns.lineplot(x = "Category", y = "Likes", data=df_filtered1, ax = ax1)
ax1.set_title('Likes increasing by dates')
ax1.set_xlabel('')
ax1.set_ylabel('Likes')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 6
#       3 ax0 = fig.add_subplot(1,2,1)
#       4 ax1 = fig.add_subplot(1,2,2)
# ----> 6 sns.boxplot(x="Category", y="Likes", data=df_filtered, ax=ax0, vert=False)
#       7 ax0.set_title('Box plot of Category with respect to Likes')
#       8 ax0.set_xlabel('Likes')
#
# File C:\Abdullah\Anaconda\Lib\site-packages\seaborn\categorical.py:2239, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     ax = plt.gca()
#    2237 kwargs.update(dict(whis=whis))
# -> 2239 plotter.plot(ax, kwargs)
#    2240 return ax
#
# File C:\Abdullah\Anaconda\Lib\site-packages\seaborn\categorical.py:888, in _BoxPlotter.plot(self, ax, boxplot_kws)
#     886 def plot(self, ax, boxplot_kws):
#     887     """Make the plot."""
# ...

# %%
df = pd.DataFrame(data)
df.to_csv("SocialMediaUsage.csv", index=False)
